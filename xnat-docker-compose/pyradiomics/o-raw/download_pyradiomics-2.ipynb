# %% [markdown]
# # Batch download of NRRD from XNAT collection

# %%
import os, subprocess, glob
import glob
import shutil
import xnat #needed for reading and writing to/from XNAT

# %%
def cleanup_temp_folder(dirt):
    if os.path.exists(dirt):
        shutil.rmtree(dirt)
        os.makedirs(dirt)
    if not os.path.exists(dirt):
        os.makedirs(dirt)

# %%
#------------------------- USER SETTINGS -------------------------------

# set up XNAT login credentials here
# .......................
xnatUrl = 'http://172.20.0.4:80'  #change me! e.g. 'http://localhost:8081/'
# - check the url using docker network inspect on the package defaul network, find the web application nginx
# - the procedure is
# - docker network ls
# - find your docker network bridge running all the xnat and python images, eg xnat-docker-compose-master_default
# - copy the network id on the left hand side
# - docker network inspect [the network id from above]
# - scroll down a little and find the docker IP network address of the nginx gateway
#
#xnatUrl = 'https://xnat.bmia.nl'
xnatUser = 'admin'  #change me!
#xnatUser = 'leonardwee'
xnatPass = 'admin'  #change me!
xnatProject = 'hn1-strategy'  #change me!

# %% [markdown]
# ### main section

# %%
PyradiomicsWorkingDir = './pre-process-RADIOMICS'
PyradiomicsSetLabel = 'pyr_'

# %%
#CAREFUL - empties the following before filling it up from XNAT
cleanup_temp_folder(PyradiomicsWorkingDir)

# %%
# -----------------------------------------------------------
with xnat.connect(xnatUrl, user=xnatUser, password=xnatPass) as session:
    myProject = session.projects[xnatProject]
    mySubjectsList = myProject.subjects.values()
    for s in mySubjectsList:
            mySubjectID = s.label
            mySubject = myProject.subjects[mySubjectID]
            myExperimentsList = mySubject.experiments.values()
            for e in myExperimentsList:
                myExperimentID = e.label
                myExperiment = mySubject.experiments[myExperimentID]
                myResourcesList = myExperiment.resources.values()
                for r in myResourcesList:
                    myResourceID = r.label
                    if myResourceID.startswith(PyradiomicsSetLabel):
                        myResource = myExperiment.resources[myResourceID]
                        for i in range(len(myResource.files)):
                            myFile = myResource.files[i].data['Name']
                            if myFile.startswith('GTV'):
                                myStem = mySubjectID + '_' + myResourceID + '.csv'
                                try:
                                    myResource.files[0].download(os.path.join(PyradiomicsWorkingDir,myStem))
                                except:
                                    print('FAILURE - could not save ' + os.path.join(PyradiomicsWorkingDir,myStem))
# Out:
# [WARNING] Detected a redirect from http://172.20.0.4:80 to http://172.20.0.4/, using http://172.20.0.4/ from now on
# 100% of  47.1 KiB |################################|  10.6 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  10.9 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|   7.9 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   8.1 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   7.1 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   8.6 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   8.8 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   6.6 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   6.4 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|  14.4 MiB/s Time:  0:00:00
# 100% of  46.8 KiB |################################|   7.3 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   8.1 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   9.5 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   8.4 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   8.9 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  10.5 MiB/s Time:  0:00:00
# 100% of  46.0 KiB |################################|   7.8 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|
MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   8.4 MiB/s Time:  0:00:00
# 100% of  47.4 KiB |################################|  10.0 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  10.5 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|  10.7 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   7.3 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  14.7 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   7.7 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  15.8 MiB/s Time:  0:00:00
# 100% of  47.0 KiB |################################|  15.9 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  18.0 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  11.0 MiB/s Time:  0:00:00
# 100% of  46.2 KiB |################################|  16.5 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  15.5 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   8.2 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|  12.1 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  14.5 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  19.6 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   9.9 MiB/s Time:  0:00:00
# 100% of  47.0 KiB |################################|  21.7 MiB/s Time:  0:00:00
# 100% of  46.6 KiB |################################|  13.0 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|  14.6 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  10.0 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   9.3 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  20.7 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  10.8 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   9.2 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  11.3 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|  11.9 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  14.2 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  11.0 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  17.7 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  12.8 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  20.6 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  10.9 MiB/s Time:  0:00:00
# 100% of  47.0 KiB |################################|  18.0 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   7.7 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  13.1 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   7.2 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|  16.8 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  15.0 MiB/s Time:  0:00:00
# 100% of  46.9 KiB |################################|  12.8 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   9.7 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|  10.6 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  16.4 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  20.7 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  17.4 MiB/s Time:  0:00:00
# 100% of  46.7 KiB |################################|  10.3 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|  12.4 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  10.1 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  14.9 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   9.2 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  13.6 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  11.1 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   7.9 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|  14.3 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  12.3 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  19.2 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  13.6 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   5.7 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  12.3 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  12.5 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  18.7 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  10.0 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|   9.9 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  10.4 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   9.1 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   9.3 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   8.6 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   8.4 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  12.4 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  10.5 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  19.2 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   9.3 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  13.9 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  11.1 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  16.6 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   8.2 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   9.3 MiB/s Time:  0:00:00
# 100% of  47.0 KiB |################################|  12.1 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  23.6 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  19.4 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  14.9 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  13.0 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  10.0 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   9.7 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  13.7 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|   9.7 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|   9.8 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  19.6 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|  20.2 MiB/s Time:  0:00:00
# 100% of  47.0 KiB |################################|  15.1 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  12.4 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  10.2 MiB/s Time:  0:00:00
# 100% of  47.1 KiB |################################|  19.2 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  12.7 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  19.7 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  16.0 MiB/s Time:  0:00:00
# 100% of  47.2 KiB |################################|  14.1 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  16.8 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  11.7 MiB/s Time:  0:00:00
# 100% of  47.3 KiB |################################|  13.9 MiB/s Time:  0:00:00

# %%
import pandas as pd

all_files = glob.glob(PyradiomicsWorkingDir + "/*.csv")
li = []

for fname in all_files:
    #temp = fname.split('.')[1].split('/')[-1]
    #subj = temp.split('_')[0]
    #mask = temp.split('_')[-1]
    try :
        df = pd.read_csv(fname, index_col=None, header=0)
        #df.insert(0, 'Subject_label', subj)
        #df.insert(1, 'ROI_label', mask)
        li.append(df)
    except :
        print("This did not have the expected data!")

frame = pd.concat(li, axis=0, ignore_index=True)

frame.to_csv('./plastimatch_version_hn1_strategy_wavelets.csv', index=False)
